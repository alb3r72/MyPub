# %% [markdown]
# # Jupyter Notebook Assignment

# %% [markdown]
# This notebook is created for an assignment for the IBM Data Science certificate.

# %% [markdown]
# ### Data Sciences Languages:
# * Python
# * R
# * Julia

# %% [markdown]
# ###Data Sciences Libraries:
# * Pandas
# * SciPy
# * Scikit-learn

# %% [markdown]
# |Data Science Tools|
# ------
# |Apache Spark|
# |TensorFlow|
# |Tableau|

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python:<br>
# 2+3<br>
# 3*4<br>
# (3+2)*4

# %%
# Here is an example of arithmetic expressions
(2+3)*4
# Out:
# 20

# %%
# Convert minutes to seconds
min = 200
hours = min/60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## **Objectives:** <br>
# Popular Tools for Data Science:
# <ul>
#  <li>Apache Spark</li>
#  <li>TensorFlow</li>
#  <li>Tableau</li>
#  <li>KNIME</li>
#  <li>Apache Hadoop</li>
# </ul>

# %% [markdown]
# ## **Author**: <br>
# Albert Li
